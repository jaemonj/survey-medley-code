# %% [markdown]
# # Run group F-test

# %% [markdown]
# Run an F-test comparing all {questionnaire} vs. grit regressors, using the outputs from the brain-behavior slope analysis adjusted for question length.

# %%
import glob
import re
import pandas as pd
import nibabel as nf
from nilearn import masking
from nilearn.plotting import plot_design_matrix

from randomise_prep import setup_randomise_tfce
from survey_medley_code.config_loader import load_config

# %%
cfg = load_config()

# %%
root = '/oak/stanford/groups/russpold/data/uh2/aim1'

question_output_path = (
    cfg.output_root / 'within_subject_question_estimates/adjusted_within_subject_results'
    )
activation_maps = glob.glob(f'{question_output_path}/*/*.nii.gz')
sub_ids = sorted(set([re.search('_sub_(.*).nii.gz', val).group(1) for val in activation_maps]))

grit_questions = ["Q01", "Q02", "Q03", "Q04", "Q05", "Q06", "Q07", "Q08"]
brief_questions = ["Q09", "Q10", "Q11", "Q12", "Q13", "Q14", "Q15", "Q16", "Q17", "Q18", "Q19", "Q20", "Q21"]
future_time_questions = ["Q22", "Q23", "Q24", "Q25", "Q26", "Q27", "Q28", "Q29", "Q30", "Q31"]
upps_questions = ["Q32", "Q33", "Q34", "Q35", "Q36", "Q37"]
impulsive_venture_questions = ["Q38", "Q39", "Q40"]
questionnaires = {"grit": grit_questions, "brief": brief_questions, "future_time": future_time_questions, "upps": upps_questions, "impulsive_venture": impulsive_venture_questions}

# %%
contrast_estimates = []
estimates_per_subject = {} # keep track of which questionnaire contrasts each subject has

# we will remove subjects with no, or outlying, grit contrast, as this is our baseline questionnaire
grit_sub_file = cfg.output_root / f'within_subject_brain_behavior_by_questionnaire/within_subject_results/outlier_assessment/subjects_outlier_percent_lt_8_contrast_grit.txt'
grit_sub_list = grit_sub_file.read_text().splitlines()
future_time_sub_file = cfg.output_root / f'within_subject_brain_behavior_by_questionnaire/within_subject_results/outlier_assessment/subjects_outlier_percent_lt_8_contrast_future_time.txt'
future_time_sub_list = future_time_sub_file.read_text().splitlines()
brief_sub_file = cfg.output_root / f'within_subject_brain_behavior_by_questionnaire/within_subject_results/outlier_assessment/subjects_outlier_percent_lt_8_contrast_brief.txt'
brief_sub_list = brief_sub_file.read_text().splitlines()
impulsive_sub_file = cfg.output_root / f'within_subject_brain_behavior_by_questionnaire/within_subject_results/outlier_assessment/subjects_outlier_percent_lt_8_contrast_impulsive_venture.txt'
impulsive_sub_list = impulsive_sub_file.read_text().splitlines()
upps_sub_file = cfg.output_root / f'within_subject_brain_behavior_by_questionnaire/within_subject_results/outlier_assessment/subjects_outlier_percent_lt_8_contrast_upps.txt'
upps_sub_list = upps_sub_file.read_text().splitlines()

good_sub_list = list(set(grit_sub_list) & set(future_time_sub_list) & set(brief_sub_list) & set(impulsive_sub_list) & set(upps_sub_list))

for sub_id in good_sub_list:
    sub_contrast_estimates = glob.glob(f'{root}/derivatives/survey_medley_results/within_subject_brain_behavior_by_questionnaire/adjusted_within_subject_results/{sub_id}/*behavioral_measures_effect_size_sub_{sub_id}*')
    estimates_per_subject[sub_id] = []
    for questionnaire in questionnaires:
        contrast_present = False
        filename = f'{root}/derivatives/survey_medley_results/within_subject_brain_behavior_by_questionnaire/adjusted_within_subject_results/{sub_id}/{questionnaire}_behavioral_measures_effect_size_sub_{sub_id}.nii.gz'
        if filename in sub_contrast_estimates:
            contrast_estimates.append(filename)
            contrast_present = True
        estimates_per_subject[sub_id].append(contrast_present)

mask_path = (
    cfg.output_root / 'assess_subject_bold_dropout/group_mask_intersection_30pct.nii.gz'
)

# Create design matrix
design_matrix = pd.DataFrame()
# Add subject indicator regressors
start = 0
for sub_id in good_sub_list:
    one_indices = list(range(start, sum(estimates_per_subject[sub_id]) + start))
    start = one_indices[-1] + 1
    col = [1 if i in one_indices else 0 for i in range(len(contrast_estimates))]
    design_matrix[sub_id] = col
# Add questionnaire comparison regressors
comparison_list = ['brief_vs_grit', 'future_time_vs_grit', 'upps_vs_grit', 'impulsive_venture_vs_grit']
for i in range(4):
    col = []
    for sub_id in good_sub_list:
        if (estimates_per_subject[sub_id][i + 1]) and (estimates_per_subject[sub_id][0]):
            sub_one_indices = [-1 if j == 0 else 1 if j == sum(estimates_per_subject[sub_id][:(i + 1)]) else 0 for j in range(sum(estimates_per_subject[sub_id]))]
        else:
            sub_one_indices = [0 for j in range(sum(estimates_per_subject[sub_id]))]
        col = col + sub_one_indices
    design_matrix[comparison_list[i]] = col

design_matrix_plot = plot_design_matrix(design_matrix)

# %%
t_contrasts = {
    "brief_vs_grit": "brief_vs_grit",
    "future_time_vs_grit": "future_time_vs_grit",
    "upps_vs_grit": "upps_vs_grit",
    "impulsive_venture_vs_grit": "impulsive_venture_vs_grit"
}

f_test = {"omnibus_f": ["brief_vs_grit", "future_time_vs_grit", "upps_vs_grit", "impulsive_venture_vs_grit"]}

script_path = setup_randomise_tfce(
    input_files=contrast_estimates,
    group_mask=mask_path,
    output_directory='/oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/questionnaire_brain_behavior_slope_ftest/adjusted_output_glm_ftest',
    analysis_type="glm",
    num_perm=5000,
    design_matrix=design_matrix,
    contrast=t_contrasts,
    ftest=f_test,
    rename_output=True
)
# Out:
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/questionnaire_brain_behavior_slope_ftest/adjusted_output_glm_ftest/input_data4d.nii.gz

# %% [markdown]
# # Create design.grp file

# %%
grp_path = '/oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/questionnaire_brain_behavior_slope_ftest/adjusted_output_glm_ftest/design.grp'
with open(grp_path, 'w') as f:
  f.write('/NumWaves  1\n')
  f.write(f'/NumPoints  {len(contrast_estimates)}\n')
  f.write('\n')
  f.write('/Matrix\n')
  group_membership = 1
  for sub in good_sub_list:
    for i in range(sum(estimates_per_subject[sub])):
      f.write(f'{group_membership}\n')
    group_membership += 1

# %% [markdown]
# Before running the randomise_call.sh script, amend the randomise call that is created to include a flag -e design.grp.

# %% [markdown]
# # Plot figures

# %% [markdown]
# We can plot the F-stat map thresholded at p < 0.05, and compare this with the F-stat map from the F-test that used all 40 questions.

# %%
from nilearn import plotting
import numpy as np

# %%
z_slices = [-20, -10, 0, 10, 20, 30, 40, 50, 60, 70]
output_path = f'{root}/derivatives/survey_medley_results/questionnaire_brain_behavior_slope_ftest/adjusted_output_glm_ftest'

# Plot F-stat p-value maps
fstat_pvalue_map = nf.load(f'{output_path}/glm_tfce_corrp_fstat1.nii.gz')
plotting.plot_stat_map(
            fstat_pvalue_map,
            display_mode='z',
            cut_coords=z_slices,
            colorbar=True,
            cmap='YlOrRd_r', 
            vmin=0, 
            vmax=1,
            threshold=0.95, 
            title=f'F-stat from analysis by questionnaire (1minuspvalue > 0.95)'
        )
plotting.show()

old_fstat_pvalue_map = nf.load(f'{root}/derivatives/survey_medley_results/within_subject_brain_behavior_analysis/output_adjusted_twosided_onesample_t_test/onesample_2sided_tfce_corrp_fstat1.nii.gz')
plotting.plot_stat_map(
            old_fstat_pvalue_map,
            display_mode='z',
            cut_coords=z_slices,
            colorbar=True,
            cmap='YlOrRd_r', 
            vmin=0, 
            vmax=1,
            threshold=0.95, 
            title=f'F-stat from analysis of all 40 questions (1minuspvalue > 0.95)'
        )
plotting.show()

# Look at the overlap between the two maps
fstat_data = fstat_pvalue_map.get_fdata()
old_fstat_data = old_fstat_pvalue_map.get_fdata()

binary_fstat_data = (fstat_data > 0.95).astype(int)
binary_old_fstat_data = (old_fstat_data > 0.95).astype(int)
intersection = binary_fstat_data * binary_old_fstat_data
overlap_image = nf.Nifti1Image(intersection, fstat_pvalue_map.affine, fstat_pvalue_map.header)
plotting.plot_stat_map(
            overlap_image,
            display_mode='z',
            cut_coords=z_slices,
            colorbar=True,
            cmap='YlOrRd_r', 
            vmin=0, 
            vmax=1,
            title=f'Intersecting voxels from both F-tests'
        )
plotting.show()
overlap_fraction = np.sum(intersection) / np.sum((binary_fstat_data + binary_old_fstat_data) > 0)
print(f'Overlap fraction: {overlap_fraction:.3f}')
# Out:
# Overlap fraction: 0.230

# %% [markdown]
# Also, try plotting the uncorrected t-stat maps.

# %%
contrast_list = ['brief_vs_grit', 'future_time_vs_grit', 'upps_vs_grit', 'impulsive_venture_vs_grit']
for i in range(4):
  tstat_map = nf.load(f'{output_path}/glm_tstat{i + 1}.nii.gz')
  plotting.plot_stat_map(
            tstat_map,
            display_mode='z',
            cut_coords=z_slices,
            threshold=2.0, 
            colorbar=True,
            title=f'Uncorrected {contrast_list[i]} t-stat (thresholded at 2)'
        )
plotting.show()
