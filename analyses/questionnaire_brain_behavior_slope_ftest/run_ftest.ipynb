# %% [markdown]
# # Run group F-test

# %% [markdown]
# Run an F-test comparing all {questionnaire} vs. grit regressors.

# %%
import glob
import re
import pandas as pd
import nibabel as nf
from nilearn import masking
from nilearn.plotting import plot_design_matrix

from randomise_prep import setup_randomise_tfce
from survey_medley_code.config_loader import load_config

# %%
cfg = load_config()

# %%
root = '/oak/stanford/groups/russpold/data/uh2/aim1'
slope_output_path = (
    cfg.output_root
    / 'within_subject_brain_behavior_by_questionnaire/within_subject_results'
)

# %%
def retrieve_subject_data(inclusion_criteria, slope_output_path):
    questionnaires = ["grit", "brief", "future_time", "upps"]
    contrast_estimates = []
    estimates_per_subject = {} # keep track of which questionnaire contrasts each subject has
    inclusion_df = pd.read_csv(slope_output_path / 'group_model_inclusion.csv')
    sub_list = list(set(inclusion_df['sub_id']))
    good_sub_list = []
    for sub_id in sub_list:
        str_sub_id = str(sub_id).zfill(3)
        estimates_per_subject[sub_id] = []
        for questionnaire in questionnaires:
            condition_1 = inclusion_df['questionnaire'] == questionnaire
            condition_2 = inclusion_df['entry_inclusion_criteria'] == inclusion_criteria
            condition_3 = inclusion_df['sub_id'] == sub_id
            include_contrast = inclusion_df.loc[condition_1 & condition_2 & condition_3, 'include_in_analysis'].iloc[0]
            if include_contrast:
                filename = f'{root}/derivatives/survey_medley_results/within_subject_brain_behavior_by_questionnaire/within_subject_results/{inclusion_criteria}/{str_sub_id}/{questionnaire}_responses_behavioral_measures_effect_size_sub_{str_sub_id}.nii.gz'
                contrast_estimates.append(filename)
                good_sub_list.append(sub_id)
            estimates_per_subject[sub_id].append(include_contrast)
    good_sub_list = list(set(good_sub_list))
    return good_sub_list, contrast_estimates, estimates_per_subject

# %%
def create_design_matrix(sub_list, estimates_per_subject, contrast_estimates):
    design_matrix = pd.DataFrame()
    # Add subject indicator regressors
    start = 0
    for sub_id in sub_list:
        one_indices = list(range(start, sum(estimates_per_subject[sub_id]) + start))
        start = one_indices[-1] + 1
        col = [1 if i in one_indices else 0 for i in range(len(contrast_estimates))]
        design_matrix[sub_id] = col
    # Add questionnaire comparison regressors
    comparison_list = ['brief_vs_grit', 'future_time_vs_grit', 'upps_vs_grit']
    for i in range(3):
        col = []
        for sub_id in sub_list:
            if (estimates_per_subject[sub_id][i + 1]) and (estimates_per_subject[sub_id][0]):
                sub_one_indices = [-1 if j == 0 else 1 if j == sum(estimates_per_subject[sub_id][:(i + 1)]) else 0 for j in range(sum(estimates_per_subject[sub_id]))]
            else:
                sub_one_indices = [0 for j in range(sum(estimates_per_subject[sub_id]))]
            col = col + sub_one_indices
        design_matrix[comparison_list[i]] = col

    design_matrix_plot = plot_design_matrix(design_matrix)
    return design_matrix

# %% [markdown]
# # Set up F-test for each inclusion criteria
# For each inclusion criteria, create a design matrix and a randomise call.

# %%
mask_path = (
    cfg.output_root / 'assess_subject_bold_dropout/group_mask_intersection_30pct.nii.gz'
)

t_contrasts = {
    "brief_vs_grit": "brief_vs_grit",
    "future_time_vs_grit": "future_time_vs_grit",
    "upps_vs_grit": "upps_vs_grit"
}
f_test = {"omnibus_f": ["brief_vs_grit", "future_time_vs_grit", "upps_vs_grit"]}

all_dirs = [d for d in slope_output_path.iterdir() if d.is_dir()]
inclusion_criterias = [d.name for d in all_dirs]
for criteria in inclusion_criterias:
    sub_list, contrast_estimates, estimates_per_subject = retrieve_subject_data(criteria, slope_output_path)
    design_matrix = create_design_matrix(sub_list, estimates_per_subject, contrast_estimates)
    script_path = setup_randomise_tfce(
        input_files=contrast_estimates,
        group_mask=mask_path,
        output_directory=f'/oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/questionnaire_brain_behavior_slope_ftest/output_glm_ftest_{criteria}',
        analysis_type="glm",
        num_perm=5000,
        design_matrix=design_matrix,
        contrast=t_contrasts,
        ftest=f_test,
        rename_output=True
    )
    # create design.grp file
    grp_path = f'/oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/questionnaire_brain_behavior_slope_ftest/output_glm_ftest_{criteria}/design.grp'
    with open(grp_path, 'w') as f:
        f.write('/NumWaves  1\n')
        f.write(f'/NumPoints  {len(contrast_estimates)}\n')
        f.write('\n')
        f.write('/Matrix\n')
        group_membership = 1
        for sub in sub_list:
            for i in range(sum(estimates_per_subject[sub])):
                f.write(f'{group_membership}\n')
            group_membership += 1
# Out:
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/questionnaire_brain_behavior_slope_ftest/output_glm_ftest_min_obs_5_min_unique_3_min_obs_binary_None/input_data4d.nii.gz
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/questionnaire_brain_behavior_slope_ftest/output_glm_ftest_min_obs_5_min_unique_2_min_obs_binary_2/input_data4d.nii.gz
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/questionnaire_brain_behavior_slope_ftest/output_glm_ftest_min_obs_6_min_unique_3_min_obs_binary_None/input_data4d.nii.gz

# %% [markdown]
# # Note: Before running the randomise_call.sh scripts, amend the randomise call that are created to include a -e design.grp flag.

# %% [markdown]
# # Plot figures

# %% [markdown]
# We can plot the F-stat map thresholded at p < 0.05, and compare this with the F-stat map from the F-test that used all 40 questions.

# %%
from nilearn import plotting
import numpy as np

# %%
z_slices = [-20, -10, 0, 10, 20, 30, 40, 50, 60, 70]
output_path = (
    cfg.output_root / 'questionnaire_brain_behavior_slope_ftest'
)
all_dirs = [d for d in output_path.iterdir() if d.is_dir()]
inclusion_criterias = [d.name for d in all_dirs]
for criteria in inclusion_criterias:
    print(f"F-stat p-value map for {criteria}")
    # Plot F-stat p-value maps
    fstat_pvalue_map = nf.load(f'{output_path}/{criteria}/glm_tfce_corrp_fstat1.nii.gz')
    plotting.plot_stat_map(
                fstat_pvalue_map,
                display_mode='z',
                cut_coords=z_slices,
                colorbar=True,
                cmap='YlOrRd_r', 
                vmin=0, 
                vmax=1,
                threshold=0.95, 
                title=f'F-stat from analysis by questionnaire (1minuspvalue > 0.95)'
            )
    plotting.show()

    old_fstat_pvalue_map = nf.load(f'{root}/derivatives/survey_medley_results/within_subject_brain_behavior_analysis/output_twosided_onesample_t_test/onesample_2sided_tfce_corrp_fstat1.nii.gz')
    plotting.plot_stat_map(
                old_fstat_pvalue_map,
                display_mode='z',
                cut_coords=z_slices,
                colorbar=True,
                cmap='YlOrRd_r', 
                vmin=0, 
                vmax=1,
                threshold=0.95, 
                title=f'F-stat from analysis of all 40 questions (1minuspvalue > 0.95)'
            )
    plotting.show()

    # Look at the overlap between the two maps
    fstat_data = fstat_pvalue_map.get_fdata()
    old_fstat_data = old_fstat_pvalue_map.get_fdata()

    binary_fstat_data = (fstat_data > 0.95).astype(int)
    binary_old_fstat_data = (old_fstat_data > 0.95).astype(int)
    intersection = binary_fstat_data * binary_old_fstat_data
    overlap_image = nf.Nifti1Image(intersection, fstat_pvalue_map.affine, fstat_pvalue_map.header)
    plotting.plot_stat_map(
                overlap_image,
                display_mode='z',
                cut_coords=z_slices,
                colorbar=True,
                cmap='YlOrRd_r', 
                vmin=0, 
                vmax=1,
                title=f'Intersecting voxels from both F-tests'
            )
    plotting.show()
    overlap_fraction = np.sum(intersection) / np.sum((binary_fstat_data + binary_old_fstat_data) > 0)
    print(f'Overlap fraction: {overlap_fraction:.3f}')
# Out:
# F-stat p-value map for output_glm_ftest_min_obs_5_min_unique_3_min_obs_binary_None
# /tmp/ipykernel_22275/524410002.py:11: UserWarning: empty mask
#   plotting.plot_stat_map(
# /tmp/ipykernel_22275/524410002.py:46: UserWarning: empty mask
#   plotting.plot_stat_map(
# Overlap fraction: 0.000
# F-stat p-value map for output_glm_ftest_min_obs_6_min_unique_3_min_obs_binary_None
# Overlap fraction: 0.000
# F-stat p-value map for output_glm_ftest_min_obs_5_min_unique_2_min_obs_binary_2
# Overlap fraction: 0.000

# %% [markdown]
# Also, try plotting the uncorrected t-stat maps.

# %%
contrast_list = ['brief_vs_grit', 'future_time_vs_grit', 'upps_vs_grit']
for criteria in inclusion_criterias:
  print(f"Uncorrected t-stat maps for {criteria}")
  for i in range(3):
    tstat_map = nf.load(f'{output_path}/{criteria}/glm_tstat{i + 1}.nii.gz')
    plotting.plot_stat_map(
              tstat_map,
              display_mode='z',
              cut_coords=z_slices,
              threshold=2.0, 
              colorbar=True,
              title=f'Uncorrected {contrast_list[i]} t-stat (thresholded at 2)'
          )
  plotting.show()
# Out:
# Uncorrected t-stat maps for output_glm_ftest_min_obs_5_min_unique_3_min_obs_binary_None
# Uncorrected t-stat maps for output_glm_ftest_min_obs_6_min_unique_3_min_obs_binary_None
# Uncorrected t-stat maps for output_glm_ftest_min_obs_5_min_unique_2_min_obs_binary_2
