# %%
# !pip install -e ./randomise-prep
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///home/users/jaemon/randomise-prep
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: ipykernel>=6.30.1 in ./.local/lib/python3.12/site-packages (from randomise-prep==0.1.0) (6.30.1)
# Requirement already satisfied: nilearn>=0.9.0 in ./.local/lib/python3.12/site-packages (from randomise-prep==0.1.0) (0.10.4)
# Requirement already satisfied: numpy>=1.20.0 in ./.local/lib/python3.12/site-packages (from randomise-prep==0.1.0) (2.1.0)
# Requirement already satisfied: pandas>=1.3.0 in ./.local/lib/python3.12/site-packages (from randomise-prep==0.1.0) (2.2.2)
# Requirement already satisfied: comm>=0.1.1 in ./.local/lib/python3.12/site-packages (from ipykernel>=6.30.1->randomise-prep==0.1.0) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./.local/lib/python3.12/site-packages (from ipykernel>=6.30.1->randomise-prep==0.1.0) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in ./.local/lib/python3.12/site-packages (from ipykernel>=6.30.1->randomise-prep==0.1.0) (9.4.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in ./.local/lib/python3.12/site-packages (from ipykernel>=6.30.1->randomise-prep==0.1.0) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.local/lib/python3.12/site-packages (from ipykernel>=6.30.1->randomise-prep==0.1.0) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.local/lib/python3.12/site-packages (from ipykernel>=6.30.1->randomise-prep==0.1.0) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in ./.local/lib/python3.12/site-packages (from ipykernel>=6.30.1->randomise-prep==0.1.0) (1.6.0)
# Requirement already satisfied: packaging>=22 in /share/software/user/open/python/3.12.1/lib/python3.12/site-packages (from ipykernel>=6.30.1->randomise-prep==0.1.0) (23.2)
# Requirement already satisfied: psutil>=5.7 in ./.local/lib/python3.12/site-packages (from ipykernel>=6.30.1->randomise-prep==0.1.0) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in ./.local/lib/python3.12/site-packages (from ipykernel>=6.30.1->randomise-prep==0.1.0) (27.0.0)
# Requirement already satisfied: tornado>=6.2 in ./.local/lib/python3.12/site-packages (from ipykernel>=6.30.1->randomise-prep==0.1.0) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in ./.local/lib/python3.12/site-packages (from ipykernel>=6.30.1->randomise-prep==0.1.0) (5.14.3)
# Requirement already satisfied: joblib>=1.0.0 in ./.local/lib/python3.12/site-packages (from nilearn>=0.9.0->randomise-prep==0.1.0) (1.4.2)
# Requirement already satisfied: lxml in ./.local/lib/python3.12/site-packages (from nilearn>=0.9.0->randomise-prep==0.1.0) (5.3.0)
# Requirement already satisfied: nibabel>=4.0.0 in ./.local/lib/python3.12/site-packages (from nilearn>=0.9.0->randomise-prep==0.1.0) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in ./.local/lib/python3.12/site-packages (from nilearn>=0.9.0->randomise-prep==0.1.0) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in ./.local/lib/python3.12/site-packages (from nilearn>=0.9.0->randomise-prep==0.1.0) (1.5.1)
# Requirement already satisfied: scipy>=1.8.0 in ./.local/lib/python3.12/site-packages (from nilearn>=0.9.0->randomise-prep==0.1.0) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.local/lib/python3.12/site-packages (from pandas>=1.3.0->randomise-prep==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.local/lib/python3.12/site-packages (from pandas>=1.3.0->randomise-prep==0.1.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.12/site-packages (from pandas>=1.3.0->randomise-prep==0.1.0) (2024.1)
# Requirement already satisfied: decorator in ./.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.30.1->randomise-prep==0.1.0) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.30.1->randomise-prep==0.1.0) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.30.1->randomise-prep==0.1.0) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in ./.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.30.1->randomise-prep==0.1.0) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.30.1->randomise-prep==0.1.0) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in ./.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.30.1->randomise-prep==0.1.0) (2.19.2)
# Requirement already satisfied: stack_data in ./.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.30.1->randomise-prep==0.1.0) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in /share/software/user/open/python/3.12.1/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.30.1->randomise-prep==0.1.0) (4.1.0)
# Requirement already satisfied: six>=1.5 in ./.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->randomise-prep==0.1.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.12/site-packages (from requests>=2.25.0->nilearn>=0.9.0->randomise-prep==0.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.local/lib/python3.12/site-packages (from requests>=2.25.0->nilearn>=0.9.0->randomise-prep==0.1.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.local/lib/python3.12/site-packages (from requests>=2.25.0->nilearn>=0.9.0->randomise-prep==0.1.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.local/lib/python3.12/site-packages (from requests>=2.25.0->nilearn>=0.9.0->randomise-prep==0.1.0) (2024.7.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.local/lib/python3.12/site-packages (from scikit-learn>=1.0.0->nilearn>=0.9.0->randomise-prep==0.1.0) (3.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.local/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.30.1->randomise-prep==0.1.0) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./.local/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.30.1->randomise-prep==0.1.0) (0.7.0)
# Requirement already satisfied: wcwidth in ./.local/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.30.1->randomise-prep==0.1.0) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in ./.local/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.30.1->randomise-prep==0.1.0) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.local/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.30.1->randomise-prep==0.1.0) (3.0.0)
# Requirement already satisfied: pure-eval in ./.local/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.30.1->randomise-prep==0.1.0) (0.2.3)
# Building wheels for collected packages: randomise-prep
#   Building editable for randomise-prep (pyproject.toml) ... done
#   Created wheel for randomise-prep: filename=randomise_prep-0.1.0-py3-none-any.whl size=4442 sha256=cb375a5d870c9c546255277df8e88cce5c8e0f01d4d7a5b0d3f3ca20f362cd84
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k5ckrlca/wheels/a5/7b/70/cefc8cb35db3720e41d61966b58c440bde902bbaa1e1f9e104
# Successfully built randomise-prep
# Installing collected packages: randomise-prep
#   Attempting uninstall: randomise-prep
#     Found existing installation: randomise-prep 0.1.0
#     Uninstalling randomise-prep-0.1.0:
#       Successfully uninstalled randomise-prep-0.1.0
# Successfully installed randomise-prep-0.1.0
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
from randomise_prep import setup_randomise_tfce
import glob
import re
import pandas as pd
from collections import OrderedDict
from nilearn import masking
import nibabel as nib
import numpy as np

# %%
# Load all the questionnaire average NIFTI files
root = '/oak/stanford/groups/russpold/data/uh2/aim1'
questionnaire_avg_out = f'{root}/derivatives/output_surveyMedley_noderivs_rerun/questionnaire_averages'
bold_files = glob.glob(f'{questionnaire_avg_out}/*')

sub_ids = sorted(set([re.search('_sub_(.*).nii.gz', val).group(1) for val in bold_files]))
# exclude the subjects who contribute to the most dropout in the group mask (this was determined earlier by Jeanette)
excluded_subject_ids = ['234', '445']
sub_ids = [sub for sub in sub_ids if sub not in excluded_subject_ids]

# Load events files
events_files = sorted(glob.glob(f'{root}/BIDS/sub-s*/ses-[0-9]/func/*surveyMedley*modified*.tsv'))

# %% [markdown]
# # Run analysis for each questionnaire

# %%
def get_sub_event_file(sub_id, events_files):
    for file in events_files:
        if sub_id in file:
            return file

# %%
grit_questions = ["Q01", "Q02", "Q03", "Q04", "Q05", "Q06", "Q07", "Q08"]
brief_questions = ["Q09", "Q10", "Q11", "Q12", "Q13", "Q14", "Q15", "Q16", "Q17", "Q18", "Q19", "Q20", "Q21"]
future_time_questions = ["Q22", "Q23", "Q24", "Q25", "Q26", "Q27", "Q28", "Q29", "Q30", "Q31"]
upps_questions = ["Q32", "Q33", "Q34", "Q35", "Q36", "Q37"]
impulsive_venture_questions = ["Q38", "Q39", "Q40"]
questionnaires = {"grit": grit_questions, "brief": brief_questions, "future_time": future_time_questions, "upps": upps_questions, "impulsive_venture": impulsive_venture_questions}

for questionnaire in questionnaires:
    # Create a dictionary where the key is a subject who answered all questions in the questionnaire, and the value is the behavioral aggregate measure
    data_dict = OrderedDict()
    for sub_id in sub_ids:
        sub_event_file = get_sub_event_file(sub_id, events_files)
        df = pd.read_csv(sub_event_file, sep='\t')
        subset = df[df["trial_type"].isin(questionnaires[questionnaire])]
        if subset.isnull().any().any():
            continue
        else:
            avg_behavior = subset["coded_response"].mean()
            data_dict[sub_id] = avg_behavior
    
    # Create design matrix with 'centered_behavior' and 'intercept' columns
    design_matrix = pd.DataFrame()
    design_matrix["centered_behavior"] = list(data_dict.values()) - np.mean(list(data_dict.values()))
    design_matrix["intercept"] = 1
    print(design_matrix)

    contrast = {
        'behavior_slope': 'centered_behavior', 
        'overall_mean': 'intercept'
    }

    ftest = {
        'behavior_slope': ['behavior_slope'], 
        'overall_mean': ['overall_mean']
    }

    # Create NIFTI file list matching subject order in design matrix
    usable_sub_ids = [sub for sub in sub_ids if sub in data_dict]
    questionnaire_bold_files = [file for file in bold_files if questionnaire in file]
    usable_bold_files = sorted([file for file in questionnaire_bold_files if any(sub_id in file for sub_id in usable_sub_ids)])

    # Check that number of rows in design matrix matches number of bold files
    print("Number of rows in design matrix:", len(design_matrix))
    print("Number of NIFTI files:", len(usable_bold_files))

    # Make group mask
    subject_masks = glob.glob(f'{root}/derivatives/fmriprep/sub-s*/ses-['
                            f'0-9]/func/*surveyMedley*space-MNI152NLin2009cAsym*mask*.nii.gz')
    subject_masks = [mask for mask in subject_masks if any(id in mask for id in usable_sub_ids)]
    group_mask = masking.intersect_masks(subject_masks, threshold=1)
    nib.save(group_mask, f'group_mask_{questionnaire}.nii.gz')

    script_path = setup_randomise_tfce( 
        input_files=usable_bold_files,
        group_mask=f'group_mask_{questionnaire}.nii.gz',
        output_directory=f'output_glm_ftest_{questionnaire}_questionnaire',
        analysis_type='glm',
        num_perm=5000,
        design_matrix=design_matrix,
        contrast=contrast,
        ftest=ftest,
        rename_output=True,  # Rename outputs with meaningful names
    )
    print(f'Generated script: {script_path}')
# Out:
#     centered_behavior  intercept
# 0           -0.145996          1
# 1            0.197754          1
# 2            0.072754          1
# 3           -0.239746          1
# 4            0.072754          1
# ..                ...        ...
# 59          -0.145996          1
# 60           0.041504          1
# 61           0.229004          1
# 62          -0.020996          1
# 63           0.010254          1
#
# [64 rows x 2 columns]
# Number of rows in design matrix: 64
# Number of NIFTI files: 64
# Concatenating input files...
# Created 4D file: /home/users/jaemon/output_glm_ftest_grit_questionnaire/input_data4d.nii.gz
# Generated script: /home/users/jaemon/output_glm_ftest_grit_questionnaire/randomise_call.sh
#     centered_behavior  intercept
# 0           -0.047175          1
# 1            0.183594          1
# 2            0.010517          1
# 3           -0.104868          1
# 4           -0.047175          1
# ..                ...        ...
# 59          -0.181791          1
# 60           0.183594          1
# 61          -0.027945          1
# 62           0.106671          1
# 63           0.183594          1
#
# [64 rows x 2 columns]
# Number of rows in design matrix: 64
# Number of NIFTI files: 64
# Concatenating input files...
# Created 4D file: /home/users/jaemon/output_glm_ftest_brief_questionnaire/input_data4d.nii.gz
# Generated script: /home/users/jaemon/output_glm_ftest_brief_questionnaire/randomise_call.sh
#     centered_behavior  intercept
# 0              -0.305          1
# 1               0.070          1
# 2              -0.180          1
# 3              -0.355          1
# 4               0.195          1
# ..                ...        ...
# 60              0.120          1
# 61              0.120          1
# 62             -0.030          1
# 63             -0.105          1
# 64             -0.105          1
#
# [65 rows x 2 columns]
# Number of rows in design matrix: 65
# Number of NIFTI files: 65
# Concatenating input files...
# Created 4D file: /home/users/jaemon/output_glm_ftest_future_time_questionnaire/input_data4d.nii.gz
# Generated script: /home/users/jaemon/output_glm_ftest_future_time_questionnaire/randomise_call.sh
#     centered_behavior  intercept
# 0           -0.090147          1
# 1            0.132075          1
# 2           -0.034591          1
# 3           -0.145702          1
# 4           -0.312369          1
# 5            0.243187          1
# 6            0.354298          1
# 7            0.076520          1
# 8           -0.034591          1
# 9           -0.090147          1
# 10           0.298742          1
# 11          -0.256813          1
# 12           0.187631          1
# 13           0.132075          1
# 14          -0.034591          1
# 15           0.187631          1
# 16          -0.256813          1
# 17          -0.090147          1
# 18          -0.090147          1
# 19          -0.201258          1
# 20           0.076520          1
# 21          -0.201258          1
# 22          -0.256813          1
# 23          -0.201258          1
# 24          -0.201258          1
# 25           0.020964          1
# 26           0.187631          1
# 27          -0.367925          1
# 28          -0.367925          1
# 29           0.354298          1
# 30          -0.145702          1
# 31           0.243187          1
# 32           0.020964          1
# 33           0.354298          1
# 34           0.132075          1
# 35          -0.367925          1
# 36           0.132075          1
# 37          -0.201258          1
# 38           0.298742          1
# 39           0.020964          1
# 40          -0.256813          1
# 41          -0.090147          1
# 42           0.132075          1
# 43           0.354298          1
# 44          -0.145702          1
# 45           0.132075          1
# 46          -0.312369          1
# 47          -0.145702          1
# 48           0.132075          1
# 49           0.298742          1
# 50           0.076520          1
# 51           0.243187          1
# 52           0.076520          1
# Number of rows in design matrix: 53
# Number of NIFTI files: 53
# Concatenating input files...
# Created 4D file: /home/users/jaemon/output_glm_ftest_upps_questionnaire/input_data4d.nii.gz
# Generated script: /home/users/jaemon/output_glm_ftest_upps_questionnaire/randomise_call.sh
#     centered_behavior  intercept
# 0            0.760870          1
# 1            0.427536          1
# 2           -0.239130          1
# 3            0.094203          1
# 4           -0.239130          1
# 5           -0.239130          1
# 6            0.094203          1
# 7            0.094203          1
# 8           -0.239130          1
# 9           -0.239130          1
# 10          -0.239130          1
# 11           0.094203          1
# 12           0.094203          1
# 13           0.094203          1
# 14          -0.239130          1
# 15          -0.239130          1
# 16           0.427536          1
# 17          -0.239130          1
# 18           0.427536          1
# 19          -0.239130          1
# 20          -0.239130          1
# 21          -0.239130          1
# 22           0.094203          1
# 23          -0.239130          1
# 24           0.094203          1
# 25          -0.239130          1
# 26          -0.239130          1
# 27           0.094203          1
# 28           0.760870          1
# 29          -0.239130          1
# 30           0.094203          1
# 31           0.427536          1
# 32           0.427536          1
# 33           0.094203          1
# 34           0.094203          1
# 35          -0.239130          1
# 36           0.094203          1
# 37           0.094203          1
# 38           0.427536          1
# 39          -0.239130          1
# 40          -0.239130          1
# 41          -0.239130          1
# 42          -0.239130          1
# 43          -0.239130          1
# 44          -0.239130          1
# 45           0.094203          1
# Number of rows in design matrix: 46
# Number of NIFTI files: 46
# Concatenating input files...
# Created 4D file: /home/users/jaemon/output_glm_ftest_impulsive_venture_questionnaire/input_data4d.nii.gz
# Generated script: /home/users/jaemon/output_glm_ftest_impulsive_venture_questionnaire/randomise_call.sh
