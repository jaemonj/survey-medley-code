# %%
import re
from glob import glob
from pathlib import Path

# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.colors import ListedColormap
from randomise_prep import setup_randomise_tfce

from survey_medley_code.config_loader import load_config

# %%
cfg = load_config()

# %%
mask_path = (
    cfg.output_root / 'assess_subject_bold_dropout/group_mask_intersection_30pct.nii.gz'
)
question_output_path = (
    cfg.output_root / 'within_subject_unified_model/within_subject_results'
)
outlier_assessment = question_output_path / 'outlier_assessment'

# %%
sub_id = []
bold_paths = []
questionnaire = []

questionnaire_names = ['grit', 'brief', 'future_time', 'impulsive_venture', 'upps']

for questionnaire_name in questionnaire_names:
    good_sub_file = (
        outlier_assessment
        / f'subjects_outlier_percent_lt_6_contrast_{questionnaire_name}.txt'
    )
    good_subs_list = good_sub_file.read_text().splitlines()
    for good_sub in good_subs_list:
        sub_no_s = good_sub.replace('s', '')
        # Glob for matching files
        bold_paths_loop = list(
            question_output_path.glob(
                f'{sub_no_s}/{questionnaire_name}_effect_size_sub_{sub_no_s}.nii.gz'
            )
        )
        if bold_paths_loop:
            sub_id.append(sub_no_s)
            questionnaire.append(questionnaire_name)
            bold_paths.append(bold_paths_loop[0])  # take the first match
        else:
            print(
                f'Output file missing for question/subject: {questionnaire_name}/{good_sub}'
            )

# %%
df = pd.DataFrame({'subid': sub_id, 'questionnaire': questionnaire})

# Get unique subjects and questionnaires
unique_subs = sorted(df['subid'].unique())
unique_questionnaires = sorted(set(questionnaire_names) - {'brief'})

# Create column names for the design matrix
subject_columns = unique_subs
questionnaire_columns = unique_questionnaires

# Pre-allocate the design matrix with zeros
desmat_df = pd.DataFrame(
    0, index=df.index, columns=subject_columns + questionnaire_columns
)

# Fill in subject indicators
for s in unique_subs:
    desmat_df[s] = (df['subid'] == s).astype(int)

# Fill in questionnaire contrasts
for q in unique_questionnaires:
    desmat_df[q] = np.select(
        [df['questionnaire'] == q, df['questionnaire'] == 'brief'], [1, -1], default=0
    )

# Concatenate with original DataFrame if needed
result_df = pd.concat([df, desmat_df], axis=1)

# %%
plt.figure(figsize=(15, 6))
sns.heatmap(
    desmat_df, xticklabels=desmat_df.columns, yticklabels=False, cmap='tab10'
)  # ensures only -1,0,1 are mapped

plt.title('Design Matrix')
plt.xlabel('Regressors')
plt.ylabel('Observations')
plt.tight_layout()
plt.show()

# %%
from pprint import pprint

contrasts = {}

qn = questionnaire_names

for i, q1 in enumerate(qn):
    if 'brief' not in q1:
        # always add q1 vs brief
        contrasts[f'{q1}-brief'] = q1
        # only iterate over items *after* q1
        for q2 in qn[i + 1 :]:
            if 'brief' not in q2:
                contrasts[f'{q1}-{q2}'] = f'{q1} - {q2}'

pprint(contrasts)

f_test = {
    'omnibusf': [
        f'{questionnaire}-brief'
        for questionnaire in questionnaire_names
        if 'brief' not in questionnaire
    ]
}

# for key, value in contrasts.items():
#     f_test[key] = [key]

print('f tests')
pprint(f_test)
# Out:
# {'future_time-brief': 'future_time',
#  'future_time-impulsive_venture': 'future_time - impulsive_venture',
#  'future_time-upps': 'future_time - upps',
#  'grit-brief': 'grit',
#  'grit-future_time': 'grit - future_time',
#  'grit-impulsive_venture': 'grit - impulsive_venture',
#  'grit-upps': 'grit - upps',
#  'impulsive_venture-brief': 'impulsive_venture',
#  'impulsive_venture-upps': 'impulsive_venture - upps',
#  'upps-brief': 'upps'}
# f tests
# {'omnibusf': ['grit-brief',
#               'future_time-brief',
#               'impulsive_venture-brief',
#               'upps-brief']}

# %% [markdown]
# ### Note, I manually changed the randomise call
# I added the `-e design.grp` to the call as well as the `--fonly` flag (no need to run t-tests)
#
# I'm also going to add a second randomise call (since --fonly will suspend the t-stat computation) with `-R` to run only the regression.  This will give me uncorrected tstat images to work with.

# %%
output_glm_ftest = cfg.output_root / 'within_subject_unified_model/group_f_test'

script_path = setup_randomise_tfce(
    input_files=bold_paths,
    group_mask=mask_path,
    output_directory=output_glm_ftest,
    analysis_type='glm',
    num_perm=5000,
    design_matrix=desmat_df,
    contrast=contrasts,
    ftest=f_test,
    rename_output=True,
    clear_output_dir=True,
)
# Out:
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/group_f_test/input_data4d.nii.gz

# %%
# add a design.grp file
unique_subs = sorted(df['subid'].unique())
subid_map = {sub: i + 1 for i, sub in enumerate(unique_subs)}  # 1-based integers
subid_ints = df['subid'].map(subid_map)

# --- Step 2: Write to F-test text file ---
output_file = output_glm_ftest / 'design.grp'
output_file.parent.mkdir(parents=True, exist_ok=True)

with output_file.open('w') as f:
    f.write('/NumWaves 1\n')
    f.write(f'/NumPoints {len(df["subid"])}\n')
    f.write('\n')  # blank line
    f.write('/Matrix\n')
    for val in subid_ints:
        f.write(f'{val}\n')

# %% [markdown]
# ## Pairwise t's

# %%
from itertools import combinations

import nibabel as nib
import numpy as np

# Directory for outputs
base_out = Path(
    '/oak/stanford/groups/russpold/data/uh2/aim1/derivatives/'
    'survey_medley_results/within_subject_unified_model/'
    'all_paired_t_tests/paired_differences'
)

# -----------------------------------------------------
# BUILD A LOOKUP:  (sub, questionnaire) → file path
# -----------------------------------------------------

lookup = {}
for sid, qp, qname in zip(sub_id, bold_paths, questionnaire):
    lookup[(sid, qname)] = qp

# All questionnaire names present
questionnaire_names = sorted(set(questionnaire))

# -----------------------------------------------------
# LOOP OVER ALL QUESTIONNAIRE PAIRS
# -----------------------------------------------------
for qa, qb in combinations(questionnaire_names, 2):
    pairing_name = f'{qa}_minus_{qb}'
    outdir = base_out / pairing_name
    outdir.mkdir(parents=True, exist_ok=True)

    print(f'Processing pairing: {pairing_name}')

    # For every subject, check whether both images exist
    for sid in sub_id:
        keyA = (sid, qa)
        keyB = (sid, qb)

        if keyA not in lookup or keyB not in lookup:
            continue  # skip subjects missing data

        imgA = nib.load(str(lookup[keyA]))
        imgB = nib.load(str(lookup[keyB]))

        diff = imgA.get_fdata() - imgB.get_fdata()

        # Save output file
        out_path = outdir / f'{pairing_name}_{sid}.nii.gz'

        nib.Nifti1Image(diff, imgA.affine, imgA.header).to_filename(str(out_path))

        print(f'  Saved {out_path}')
# Out:
# Processing pairing: brief_minus_future_time
#   Saved /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_differences/brief_minus_future_time/brief_minus_future_time
oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_differences/impulsive_venture_minus_upps/impulsive_venture_minus_upps_649.nii.gz

# %%
base_dir = Path(
    '/oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model'
)
paired_diff_root = base_dir / 'all_paired_t_tests' / 'paired_differences'
randomise_root = base_dir / 'all_paired_t_tests'

for q1, q2 in combinations(questionnaire_names, 2):
    # --------------------------------------------
    # 1. Build the pairing name and collect files
    # --------------------------------------------
    pair_name = f'{q1}_minus_{q2}'
    diff_dir = paired_diff_root / pair_name

    bold_paths_loop = sorted(diff_dir.glob('*.nii.gz'))
    if not bold_paths_loop:
        print(f'⚠️ No paired difference images found for {pair_name}, skipping.')
        continue

    print(f'Found {len(bold_paths_loop)} paired images for {pair_name}')

    # --------------------------------------------
    # 2. Build output randomise directory
    # --------------------------------------------
    output_paired_ttest_loop = randomise_root / f'paired_test_{pair_name}'
    output_paired_ttest_loop.mkdir(parents=True, exist_ok=True)

    # --------------------------------------------
    # 3. Run TFCE randomise job
    # --------------------------------------------
    script_path = setup_randomise_tfce(
        input_files=bold_paths_loop,
        group_mask=mask_path,  # already defined earlier
        output_directory=output_paired_ttest_loop,
        analysis_type='onesample_2sided',
        num_perm=5000,
        rename_output=True,
    )

    print(f'✓ Created randomise script for {pair_name}: {script_path}')
# Out:
# Found 89 paired images for brief_minus_future_time
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_brief_minus_future_time/input_data4d.nii.gz
# Note: rename_output=True will rename _corrp_ to _1minuspvalue_ in output filenames for t-test analysis
# ✓ Created randomise script for brief_minus_future_time: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_brief_minus_future_time/randomise_call.sh
# Found 91 paired images for brief_minus_grit
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_brief_minus_grit/input_data4d.nii.gz
# Note: rename_output=True will rename _corrp_ to _1minuspvalue_ in output filenames for t-test analysis
# ✓ Created randomise script for brief_minus_grit: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_brief_minus_grit/randomise_call.sh
# Found 77 paired images for brief_minus_impulsive_venture
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_brief_minus_impulsive_venture/input_data4d.nii.gz
# Note: rename_output=True will rename _corrp_ to _1minuspvalue_ in output filenames for t-test analysis
# ✓ Created randomise script for brief_minus_impulsive_venture: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_brief_minus_impulsive_venture/randomise_call.sh
# Found 90 paired images for brief_minus_upps
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_brief_minus_upps/input_data4d.nii.gz
# Note: rename_output=True will rename _corrp_ to _1minuspvalue_ in output filenames for t-test analysis
# ✓ Created randomise script for brief_minus_upps: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_brief_minus_upps/randomise_call.sh
# Found 89 paired images for future_time_minus_grit
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_future_time_minus_grit/input_data4d.nii.gz
# Note: rename_output=True will rename _corrp_ to _1minuspvalue_ in output filenames for t-test analysis
# ✓ Created randomise script for future_time_minus_grit: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_future_time_minus_grit/randomise_call.sh
# Found 75 paired images for future_time_minus_impulsive_venture
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_future_time_minus_impulsive_venture/input_data4d.nii.gz
# Note: rename_output=True will rename _corrp_ to _1minuspvalue_ in output filenames for t-test analysis
# ✓ Created randomise script for future_time_minus_impulsive_venture: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_future_time_minus_impulsive_venture/randomise_call.sh
# Found 88 paired images for future_time_minus_upps
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_future_time_minus_upps/input_data4d.nii.gz
# Note: rename_output=True will rename _corrp_ to _1minuspvalue_ in output filenames for t-test analysis
# ✓ Created randomise script for future_time_minus_upps: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_future_time_minus_upps/randomise_call.sh
# Found 78 paired images for grit_minus_impulsive_venture
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_grit_minus_impulsive_venture/input_data4d.nii.gz
# Note: rename_output=True will rename _corrp_ to _1minuspvalue_ in output filenames for t-test analysis
# ✓ Created randomise script for grit_minus_impulsive_venture: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_grit_minus_impulsive_venture/randomise_call.sh
# Found 90 paired images for grit_minus_upps
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_grit_minus_upps/input_data4d.nii.gz
# Note: rename_output=True will rename _corrp_ to _1minuspvalue_ in output filenames for t-test analysis
# ✓ Created randomise script for grit_minus_upps: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_grit_minus_upps/randomise_call.sh
# Found 76 paired images for impulsive_venture_minus_upps
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_impulsive_venture_minus_upps/input_data4d.nii.gz
# Note: rename_output=True will rename _corrp_ to _1minuspvalue_ in output filenames for t-test analysis
# ✓ Created randomise script for impulsive_venture_minus_upps: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_unified_model/all_paired_t_tests/paired_test_impulsive_venture_minus_upps/randomise_call.sh
