# %% [markdown]
# # Within-subject analysis (adjusting for question length)

# %%
import glob
import re
from nilearn.glm.second_level import SecondLevelModel
import pandas as pd
import nibabel as nf

from survey_medley_code.config_loader import load_config
from survey_medley_code.outlier_detection_optimized import (
    generate_all_data_summaries_parallel,
)

# %%
cfg = load_config()

# %%
question_output_path = (
    cfg.output_root / 'within_subject_question_estimates/within_subject_results'
)

# %%
root = '/oak/stanford/groups/russpold/data/uh2/aim1'
activation_maps = glob.glob(f'{question_output_path}/*/*.nii.gz')

sub_ids = sorted(set([re.search('_sub_(.*).nii.gz', val).group(1) for val in activation_maps]))

# Load events files
events_files = sorted(glob.glob(f'{root}/BIDS/sub-s*/ses-[0-9]/func/*surveyMedley*modified*.tsv'))

# %%
def get_sub_event_file(sub_id, events_files):
    for file in events_files:
        if sub_id in file:
            return file

# %%
for sub in sub_ids:
    # First, make the design matrix
    design_matrix = pd.DataFrame()
    behavioral_measures = []
    chr_counts = []
    sub_event_file = get_sub_event_file(sub, events_files)
    sub_bold_files = []
    df = pd.read_csv(sub_event_file, sep='\t')
    # create behavioral measures column and character count column, making sure the responses are in order
    for i in range(40):
        str_question_num = 'Q' + str(i + 1).zfill(2)
        response = df.loc[df['trial_type'] == str_question_num, 'coded_response']
        behavior = response.values[0]
        text = df.loc[df['trial_type'] == str_question_num, 'item_text']
        chr_count = len(text.values[0])
        if not pd.isna(behavior):
            question_bold_file = f'{question_output_path}/{sub}/contrast_{str_question_num}_effect_size_sub_{sub}.nii.gz'
            if question_bold_file in activation_maps:
                sub_bold_files.append(question_bold_file)
                behavioral_measures.append(behavior)
                chr_counts.append(chr_count)
                
    design_matrix["behavioral_measures"] = behavioral_measures
    design_matrix["intercept"] = 1
    design_matrix["chr_count"] = chr_counts

    model = SecondLevelModel(n_jobs=2)
    model.fit(sub_bold_files, design_matrix=design_matrix)
    contrast_map = model.compute_contrast(second_level_contrast='behavioral_measures', output_type='effect_size')
    contrast_map_dir = (
        cfg.output_root
        / f'within_subject_brain_behavior_analysis/within_subject_results/{sub}'
    )
    contrast_map_dir.mkdir(parents=True, exist_ok=True)
    nf.save(contrast_map, f'{contrast_map_dir}/adjusted_behavioral_measures_effect_size_sub_{sub}.nii.gz')

# %% [markdown]
# # Outlier assessment

# %%
from survey_medley_code.analysis_provenance import log_provenance
from pathlib import Path
import multiprocessing
import shutil

# %%
data_root = Path(
    '/oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_brain_behavior_analysis/within_subject_results'
)


subids_loop = []
nifti_paths_loop = []
for sub in sub_ids:
    pattern = f'{sub}/adjusted_behavioral_measures_effect_size_sub_{sub}.nii.gz'
    sub_nifti_paths = list(data_root.glob(pattern))
    if len(sub_nifti_paths) == 1:
        subids_loop.append(sub)
        nifti_paths_loop.append(sub_nifti_paths[0])
    else:
        print(f'sub {sub} had {len(sub_nifti_paths)} files')
data_dict_loop = {
    'main_title': 'behavioral_measures_effect_size',
    'nifti_paths': nifti_paths_loop,
    'image_labels': subids_loop,
    'data_type_label': 'contrast estimate',
}
dict_list = [data_dict_loop]

# %%
n_cpus = multiprocessing.cpu_count()
print(f'Detected {n_cpus} CPUs')

n_workers = min(n_cpus, 20)
# Out:
# Detected 24 CPUs

# %%
outlier_root = data_root / 'adjusted_outlier_assessment'
shutil.rmtree(outlier_root, ignore_errors=True)
outlier_root.mkdir(parents=True, exist_ok=True)

# %%
this_notebook = '/oak/stanford/groups/russpold/data/uh2/aim1/analysis_code/survey_medley_code/analyses/within_subject_brain_behavior_analysis/analyze_adjusted_brain_behavior_within_subject.ipynb'

log_provenance(outlier_root, settings={'notebook_file': this_notebook})

generate_all_data_summaries_parallel(
    dict_list, n_std=3, output_dir=outlier_root, n_workers=n_workers
)
# Out:
# Finished behavioral_measures_effect_size
# PDF saved to /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_brain_behavior_analysis/within_subject_results/adjusted_outlier_assessment/outlier_analysis.pdf
# All done! PDF saved to /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_brain_behavior_analysis/within_subject_results/adjusted_outlier_assessment/outlier_analysis.pdf

# %% [markdown]
# After looking at the pdf, we will lower the cutoff percentage to 6.

# %%
outlier_output = pd.read_csv(
    outlier_root / 'percent_outlier_data.csv', dtype={'subject_label': str}
)

# %%
for contrast, df_group in outlier_output.groupby('contrast_name'):
    # Save "good" subjects (< 6) to a text file
    good_subjects = df_group[df_group['image_outlier_percentage'] < 6]['subject_label']
    txt_path = outlier_root / f'subjects_outlier_percent_lt_6_contrast_{contrast}.txt'
    good_subjects.to_csv(txt_path, index=False, header=False)

# %% [markdown]
# # Group level analysis

# %%
from randomise_prep import setup_randomise_tfce
from nilearn import masking

# %%
# outlier criteria: > 6% voxels above +/- 3SD above subject-specific mean
good_sub_file = outlier_root / 'subjects_outlier_percent_lt_6_contrast_behavioral_measures_effect_size.txt'
sub_ids = good_sub_file.read_text().splitlines()

mask_path = (
    cfg.output_root / 'assess_subject_bold_dropout/group_mask_intersection_30pct.nii.gz'
)

nifti_paths_loop = [str(path) for path in nifti_paths_loop]
contrast_estimates = [file for file in nifti_paths_loop if any(sub_id in file for sub_id in sub_ids)]

script_path = setup_randomise_tfce(
    input_files=contrast_estimates,
    group_mask=mask_path,
    output_directory="/oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_brain_behavior_analysis/output_adjusted_twosided_onesample_t_test",
    analysis_type="onesample_2sided",
    num_perm=5000
)

print(f'Generated script: {script_path}')
# Out:
# Concatenating input files...
# Created 4D file: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_brain_behavior_analysis/output_adjusted_twosided_onesample_t_test/input_data4d.nii.gz
# Generated script: /oak/stanford/groups/russpold/data/uh2/aim1/derivatives/survey_medley_results/within_subject_brain_behavior_analysis/output_adjusted_twosided_onesample_t_test/randomise_call.sh

# %% [markdown]
# Run the generated randomise_call.sh script using the submit_adjusted_randomise.sh file in 'analyses/within_subject_brain_behavior_analysis' to get the uncorrected t-stat map and F-stat p-value map before plotting them.

# %% [markdown]
# # Plot figures

# %%
from nilearn import plotting

# %%
z_slices = [-20, -10, 0, 10, 20, 30, 40, 50, 60, 70]
output_path = f'{root}/derivatives/survey_medley_results/within_subject_brain_behavior_analysis/output_adjusted_twosided_onesample_t_test'

# Plot uncorrected t-stat map
tstat_map = nf.load(f'{output_path}/uncorrected_tstat1.nii.gz')
plotting.plot_stat_map(
            tstat_map,
            display_mode='z',
            cut_coords=z_slices,
            threshold=2.0, 
            colorbar=True,
            title=f'Uncorrected t-stat (thresholded at 2)'
        )
plotting.show()

# %%
# Plot F-stat p-value map
fstat_pvalue_map = nf.load(f'{output_path}/onesample_2sided_tfce_corrp_fstat1.nii.gz')
plotting.plot_stat_map(
            fstat_pvalue_map,
            display_mode='z',
            cut_coords=z_slices,
            colorbar=True,
            cmap='RdYlGn', 
            vmin=0, 
            vmax=1,
            threshold=0.95, 
            title=f'F-stat (1minuspvalue > 0.95)'
        )
plotting.show()
